# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import re

pd.set_option('max_columns', 500)

# For plotting
from itertools import cycle

plt.style.use("ggplot")
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %% [markdown]
# # Load in the Dataset and Parse Tweet Text:

# %%
tweets = pd.read_csv('../input/wordle-tweets/tweets.csv')

# %%
def process_tweets(tweets):
    tweets['tweet_datetime'] = pd.to_datetime(tweets['tweet_date'])
    tweets['tweet_date'] = tweets['tweet_datetime'].dt.date
    tweets['wordle_id'] = tweets['tweet_text'].str[:10]
    tweets['n_attempts'] = tweets['tweet_text'].str[11].astype('int')
    tweets['id'] = tweets['tweet_text'].str[7:10].astype('int')
    return tweets

tweets = process_tweets(tweets)

# %% [markdown]
# ## How many tweets do we have for each date:

# %%
tweets['tweet_date'].value_counts() \
    .plot(figsize=(10, 5), title='Wordle Tweets by Day',
          color=color_pal[2], lw=5)
plt.show()

# %% [markdown]
# # Number of Attempts analysis by Wordle ID:

# %%
tweets.groupby('wordle_id')['n_attempts'].value_counts() \
    .unstack() \
    .style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_280cf_row0_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_280cf_row0_col1 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_280cf_row0_col2, #T_280cf_row1_col2, #T_280cf_row2_col2, #T_280cf_row3_col3, #T_280cf_row4_col1, #T_280cf_row5_col2, #T_280cf_row6_col2, #T_280cf_row7_col2, #T_280cf_row8_col2, #T_280cf_row9_col3, #T_280cf_row10_col2, #T_280cf_row11_col2, #T_280cf_row12_col2, #T_280cf_row13_col2, #T_280cf_row14_col2, #T_280cf_row15_col2, #T_280cf_row16_col1, #T_280cf_row17_col1, #T_280cf_row18_col1, #T_280cf_row19_col2, #T_280cf_row20_col2, #T_280cf_row21_col2, #T_280cf_row22_col2, #T_280cf_row23_col3, #T_280cf_row24_col2, #T_280cf_row25_col2, #T_280cf_row26_col2, #T_280cf_row27_col2, #T_280cf_row28_col2, #T_280cf_row29_col2, #T_280cf_row30_col3, #T_280cf_row31_col2, #T_280cf_row32_col2, #T_280cf_row33_col2, #T_280cf_row34_col2, #T_280cf_row35_col3, #T_280cf_row36_col2, #T_280cf_row37_col2, #T_280cf_row38_col1, #T_280cf_row39_col2, #T_280cf_row40_col2, #T_280cf_row41_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_280cf_row0_col3, #T_280cf_row32_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_280cf_row0_col4, #T_280cf_row1_col0, #T_280cf_row2_col4, #T_280cf_row3_col0, #T_280cf_row4_col4, #T_280cf_row5_col4, #T_280cf_row6_col4, #T_280cf_row7_col0, #T_280cf_row8_col0, #T_280cf_row9_col0, #T_280cf_row10_col0, #T_280cf_row11_col0, #T_280cf_row12_col4, #T_280cf_row13_col0, #T_280cf_row14_col0, #T_280cf_row15_col0, #T_280cf_row16_col4, #T_280cf_row17_col4, #T_280cf_row18_col4, #T_280cf_row19_col0, #T_280cf_row20_col4, #T_280cf_row21_col0, #T_280cf_row22_col0, #T_280cf_row23_col0, #T_280cf_row24_col0, #T_280cf_row25_col0, #T_280cf_row26_col0, #T_280cf_row27_col0, #T_280cf_row28_col0, #T_280cf_row29_col0, #T_280cf_row30_col0, #T_280cf_row31_col0, #T_280cf_row32_col0, #T_280cf_row33_col0, #T_280cf_row34_col0, #T_280cf_row35_col0, #T_280cf_row36_col0, #T_280cf_row37_col0, #T_280cf_row37_col4, #T_280cf_row38_col4, #T_280cf_row39_col0, #T_280cf_row40_col0, #T_280cf_row41_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_280cf_row1_col1 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_280cf_row1_col3, #T_280cf_row5_col3, #T_280cf_row34_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_280cf_row1_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_280cf_row2_col0, #T_280cf_row14_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_280cf_row2_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_280cf_row2_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_280cf_row3_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_280cf_row3_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_280cf_row3_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_280cf_row4_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_280cf_row4_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_280cf_row4_col3 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_280cf_row5_col0, #T_280cf_row6_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_280cf_row5_col1 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_280cf_row6_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_280cf_row6_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_280cf_row7_col1, #T_280cf_row27_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_280cf_row7_col3, #T_280cf_row12_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_280cf_row7_col4 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_280cf_row8_col1, #T_280cf_row33_col4 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_280cf_row8_col3 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_280cf_row8_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_280cf_row9_col1, #T_280cf_row17_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_280cf_row9_col2, #T_280cf_row13_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_280cf_row9_col4, #T_280cf_row37_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_280cf_row10_col1, #T_280cf_row15_col3, #T_280cf_row39_col1 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_280cf_row10_col3 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_280cf_row10_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_280cf_row11_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_280cf_row11_col3 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_280cf_row11_col4 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_280cf_row12_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_280cf_row12_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_280cf_row13_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_280cf_row13_col4 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_280cf_row14_col1 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_280cf_row14_col3 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_280cf_row15_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_280cf_row15_col4 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_280cf_row16_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_280cf_row16_col2 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_280cf_row16_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_280cf_row17_col0, #T_280cf_row24_col4 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_280cf_row17_col2, #T_280cf_row35_col4 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_280cf_row18_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_280cf_row18_col2 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_280cf_row18_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_280cf_row19_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_280cf_row19_col3 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_280cf_row19_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_280cf_row20_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_280cf_row20_col1, #T_280cf_row24_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_280cf_row20_col3 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_280cf_row21_col1, #T_280cf_row29_col3, #T_280cf_row41_col4 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_280cf_row21_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_280cf_row21_col4, #T_280cf_row40_col4 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_280cf_row22_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_280cf_row22_col3 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_280cf_row22_col4 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_280cf_row23_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_280cf_row23_col2 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_280cf_row23_col4 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_280cf_row24_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_280cf_row25_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_280cf_row25_col3 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_280cf_row25_col4, #T_280cf_row38_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_280cf_row26_col1 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_280cf_row26_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_280cf_row26_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_280cf_row27_col3 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_280cf_row27_col4 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_280cf_row28_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_280cf_row28_col3 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_280cf_row28_col4 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_280cf_row29_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_280cf_row29_col4 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_280cf_row30_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_280cf_row30_col2, #T_280cf_row34_col3

# %% [markdown]
# # How many attempts does it ususally take to solve?

# %%
ax = tweets['n_attempts'].value_counts() \
    .sort_index() \
    .plot(figsize=(10, 5),
          kind='barh',
          title='Number of Wordle Attempts',
          edgecolor='black')
ax.set_xlabel('Number of Tweets')
ax.set_ylabel('Number of Attempts Solved in')
plt.show()

# %% [markdown]
# # Parse Tweet Text:

# %%
# Make dark squares consistent
tweets['tweet_text'] = tweets['tweet_text'].str.replace('⬜','⬛')

# %%
def parse_tweet_text(tweets):
    for n in range(6):
        n += 1
        tweets[f'has_guess{n}'] = tweets['tweet_text'].str.split('\n').str[n+1] \
            .str.contains('|'.join(['🟨','⬛','🟩'])) \
            .fillna(False)

        # Parse out the tweet text
        tweets.loc[tweets[f'has_guess{n}'], f'guess{n}'] = \
                tweets['tweet_text'].str.split('\n').str[n + 1].str[:5]
        # Count number correct, misplaced, and incorrect
        tweets.loc[tweets[f'has_guess{n}'],
                       f'guess{n}_incorrect'] = tweets[f'guess{n}'].str.count('⬛')
        tweets.loc[tweets[f'has_guess{n}'],
                   f'guess{n}_wrong_spot'] = tweets[f'guess{n}'].str.count('🟨')
        tweets.loc[tweets[f'has_guess{n}'],
                   f'guess{n}_correct'] = tweets[f'guess{n}'].str.count('🟩')

        tweets.loc[tweets[f'guess{n}_correct'] == 6, 'final_guess'] = n
    return tweets

tweets = parse_tweet_text(tweets)

# %%
# Keep additional tweet text
tweets['additional_text'] = \
    tweets.loc[~tweets['tweet_text'] \
    .str.split('\n').str[-1].str.contains('🟩')] \
    ['tweet_text'].str.split('\n').str[-1]

# %% [markdown]
# # Plot Results by Attempt:

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 5), sharex=True)

for i, x in enumerate(['_correct','_wrong_spot','_incorrect']):
    col_subset = [c for c in tweets.columns if x in c]
    guess_avg = tweets[col_subset].mean()
    guess_avg.index = [f'Guess {i+1}' for i in range(6)]
    guess_avg.sort_index(ascending=False) \
        .plot(kind='barh',
              title=f'{x.strip("_").replace("_"," ").title()}',
              ax=axs[i],
              color=color_pal[i+1])
    axs[i].set_xlabel('Average Letters')
fig.suptitle('Wordle Average Results by Guess Number', fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Letter Analysis:

# %%
answer_dict = {252 : 'SPILL',
     251 : 'VIVID',
     250 : 'BLOKE',
     249 : 'TROVE',
     248 : 'THORN',
     247 : 'OTHER',
     246 : 'TACIT',
     245 : 'SWILL',
     244 : 'DODGE',
     243 : 'SHAKE',
     242 : 'CAULK',
     241 : 'AROMA',
     240 : 'CYNIC',
     239 : 'ROBIN',
     238 : 'ULTRA',
     237 : 'ULCER',
     236 : 'PAUSE',
     235 : 'HUMOR',
     234 : 'FRAME',
     233 : 'ELDER',
     232 : 'SKILL',
     231 : 'ALOFT',
     230 : 'PLEAT',
     229 : 'SHARD',
     228 : 'MOIST',
     227 : 'THOSE',
     204 : 'GORGE',
     205 : 'QUERY',
     206 : 'DRINK',
     207 : 'FAVOR',
     208 : 'ABBEY',
     209 : 'TANGY',
     210 : 'PANIC',
     211 : 'SOLAR',
     212 : 'SHIRE',
     213 : 'PROXY',
     214 : 'POINT',
     215 : 'ROBOT',
     216 : 'PRICK',
     217 : 'WINCE',
     218 : 'CRIMP',
     219 : 'KNOLL',
     220 : 'SUGAR',
     221 : 'WHACK',
     222 : 'MOUNT',
     223 : 'PERKY',
     224 : 'COULD',
     225 : 'WRUNG',
     226 : 'LIGHT',
}

tweets['answer'] = tweets['id'].map(answer_dict)

# %%
first_guess_correct = []
for i, d in tweets.dropna(subset=['answer']).iterrows():
    example_text = d['guess1']
    example_solution = d['answer']
    results =[x.span()[0] for x in re.finditer('🟩', example_text)]
    first_guess_letters = [example_solution[i] for i in results]
    first_guess_correct += first_guess_letters

# %%
pd.Series(first_guess_correct).value_counts(ascending=True) \
    .plot(kind='barh', figsize=(10, 5),
         title='Most Common Correct First Guess Letters',
         edgecolor='black', color=color_pal[5])
plt.show()
